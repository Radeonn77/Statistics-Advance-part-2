# %% [markdown]
# # Statistics Part-2 Assignment

# %% [markdown]
# 1.  What is hypothesis testing in statistics?
#  - Hypothesis testing is a statistical method used to make decisions or inferences about population parameters based on sample data. It involves formulating two competing hypotheses (null and alternative) and using data to determine which is more supported by the evidence.
#
# 2. What is the null hypothesis, and how does it differ from the alternative hypothesis?
#  - Null Hypothesis (H₀): Assumes no effect or no difference. It is the default or starting assumption.
#
#  - Alternative Hypothesis (H₁ or Ha): Represents what we are trying to prove — that there is an effect or difference.
#
#    - Example:
#  - H₀: μ = 50 (mean is 50)
#  - H₁: μ ≠ 50 (mean is not 50)
#
# 3. What is the significance level in hypothesis testing, and why is it important?
#  - Significance Level (α): The probability of rejecting the null hypothesis when it is true (Type I error). Common values: 0.05, 0.01.
#
#  - Importance: It sets the threshold for decision-making and helps control the likelihood of Type I errors.
#
# 4. What does a P-value represent in hypothesis testing?
#  - The P-value is the probability of obtaining a result equal to or more extreme than the observed result, assuming the null hypothesis is true.
#
# 5. How do you interpret the P-value in hypothesis testing?
#  - If P-value ≤ α: Reject H₀ (evidence supports H₁)
#
#  - If P-value > α: Fail to reject H₀ (not enough evidence against H₀)
#
# 6.  What are Type 1 and Type 2 errors in hypothesis testing?
#  - Type I Error: Rejecting H₀ when it's true (false positive).
#
#  - Type II Error: Failing to reject H₀ when it's false (false negative).
#
# 7.What is the difference between a one-tailed and a two-tailed test in hypothesis testing?
#  - One-tailed test: Tests in one direction (e.g., μ > μ₀ or μ < μ₀).
#
#  - Two-tailed test: Tests in both directions (e.g., μ ≠ μ₀).
#
# 8. What is the Z-test, and when is it used in hypothesis testing?
#  - Z-test: Used when population variance is known or sample size is large (n ≥ 30).
#
#  - Used to test means or proportions.
#
# 9.How do you calculate the Z-score, and what does it represent in hypothesis testing?
#  - Z-score = (Sample Mean - Population Mean) / (Population Std Dev / √n)
#
#  - It represents how many standard deviations the sample mean is from the population mean.
#
# 10. What is the T-distribution, and when should it be used instead of the normal distribution?
#  - Use T-distribution when the population standard deviation is unknown and sample size is small (n < 30). It is wider and has heavier tails than the normal distribution.
#
# 11. What is the difference between a Z-test and a T-test?
#  - Z-test: Known population standard deviation or large sample size.
#
#  - T-test: Unknown population standard deviation and small sample size.
#
# 12.  What is the T-test, and how is it used in hypothesis testing?
#  - T-test compares means to determine if they are significantly different.
#
#  - Types: One-sample, two-sample (independent), and paired sample t-tests.
#
# 13. What is the relationship between Z-test and T-test in hypothesis testing?
#  - Both test for mean differences.
#
#  - Z-test assumes known population variance; T-test does not.
#
#  - T-test approximates Z-test as sample size increases.
#
# 14.  What is a confidence interval, and how is it used to interpret statistical results
#  - A confidence interval (CI) gives a range within which the population parameter is expected to lie with a certain level of confidence (e.g., 95%).
#
# 15.  What is the margin of error, and how does it affect the confidence interval
#  - Margin of Error (MoE): Half the width of the confidence interval.
#
#  - Affects precision; smaller MoE = narrower CI = more precise estimate.
#
# 16. How is Bayes' Theorem used in statistics, and what is its significance
# Bayes' Theorem: Updates the probability of a hypothesis based on new evidence.
#
#  - Formula:
# 𝑃
# (
# 𝐻
# ∣
# 𝐸
# )
# =
# 𝑃
# (
# 𝐸
# ∣
# 𝐻
# )
# ⋅
# 𝑃
# (
# 𝐻
# )
# 𝑃
# (
# 𝐸
# )
# P(H∣E)=
# P(E)
# P(E∣H)⋅P(H)
# ​
#
#
#  - Significance: Used in Bayesian inference, spam filtering, diagnostics, etc.
#
# 17. What is the Chi-square distribution, and when is it used?
#  - Right-skewed distribution used in testing variance and categorical data.
#
# Used in Chi-square tests: independence and goodness-of-fit.
#
# 18.  What is the Chi-square goodness of fit test, and how is it applied?
#  - Tests if observed categorical data fits an expected distribution.
#
# 𝜒
# 2
# =
# ∑
# (
# 𝑂
# 𝑖
# −
# 𝐸
# 𝑖
# )
# 2
# 𝐸
# 𝑖
# χ
# 2
#  =∑
# E
# i
# ​
#
# (O
# i
# ​
#  −E
# i
# ​
#  )
# 2
#
# ​
#
#
# 19. What is the F-distribution, and when is it used in hypothesis testing?
#  - A ratio of two chi-square distributions.
#
#  - Used to compare variances or in ANOVA for comparing group means.
#
# 20.  What is an ANOVA test, and what are its assumptions?
# -  ANOVA (Analysis of Variance): Tests if means of ≥2 groups differ.
#
#  - Assumptions:
#
#  - Independence
#
#  - Normality
#
#  - Equal variances (homogeneity of variance)
#
# 21. What are the different types of ANOVA tests?
#  - One-way ANOVA: One independent variable.
#
#  - Two-way ANOVA: Two independent variables.
#
#  - Repeated Measures ANOVA: Same subjects tested over time.
#
# 22. What is the F-test, and how does it relate to hypothesis testing?
#  - F-test compares two variances.
#
#  - Used in ANOVA to determine if group variances are significantly different.

# %%
#1. Write a Python program to perform a Z-test for comparing a sample mean to a known population mean and interpret the results
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.proportion import proportions_ztest

# Known population parameters
population_mean = 100
population_std = 15

# Sample data
sample_data = [98, 102, 101, 99, 97, 100, 102, 98, 97, 96]
sample_mean = np.mean(sample_data)
sample_size = len(sample_data)

# Calculate Z-statistic
z_score = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))

# Calculate two-tailed p-value
p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

print(f"Z-score: {z_score:.4f}")
print(f"P-value: {p_value:.4f}")

# Interpretation
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: Sample mean is significantly different from the population mean.")
else:
    print("Fail to reject the null hypothesis: No significant difference.")
# Out:
# Z-score: -0.2108
# P-value: 0.8330
# Fail to reject the null hypothesis: No significant difference.

# %%
#2. Simulate random data to perform hypothesis testing and calculate the corresponding P-value using Python
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.proportion import proportions_ztest

# Simulating sample from normal distribution
np.random.seed(0)
data = np.random.normal(loc=52, scale=10, size=30)

# Perform one-sample t-test against population mean of 50
t_stat, p_value = stats.ttest_1samp(data, popmean=50)

print(f"T-statistic: {t_stat:.4f}")
print(f"P-value: {p_value:.4f}")
# Out:
# T-statistic: 3.2000
# P-value: 0.0033

# %%
#3. Implement a one-sample Z-test using Python to compare the sample mean with the population mean
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.proportion import proportions_ztest

# Reuse from previous, but general function for one-sample Z-test
def one_sample_z_test(sample, pop_mean, pop_std):
    n = len(sample)
    sample_mean = np.mean(sample)
    z = (sample_mean - pop_mean) / (pop_std / np.sqrt(n))
    p = 2 * (1 - stats.norm.cdf(abs(z)))
    return z, p

# Example
sample = np.random.normal(52, 10, 30)
z, p = one_sample_z_test(sample, pop_mean=50, pop_std=10)
print(f"Z-statistic: {z:.4f}, P-value: {p:.4f}")
# Out:
# Z-statistic: -0.4903, P-value: 0.6239

# %%
#4. Perform a two-tailed Z-test using Python and visualize the decision region on a plot
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.proportion import proportions_ztest

# Perform Z-test
z_stat = (np.mean(sample) - 50) / (10 / np.sqrt(len(sample)))
p_val = 2 * (1 - stats.norm.cdf(abs(z_stat)))

# Plotting decision region
x = np.linspace(-4, 4, 1000)
y = stats.norm.pdf(x)
critical_z = stats.norm.ppf(1 - 0.05 / 2)

plt.figure(figsize=(10, 5))
plt.plot(x, y, label="Z-distribution")
plt.fill_between(x, y, where=(x <= -critical_z) | (x >= critical_z), color="red", alpha=0.3, label="Rejection region")
plt.axvline(z_stat, color='blue', linestyle='--', label=f"Z-statistic = {z_stat:.2f}")
plt.title("Two-Tailed Z-Test Decision Region")
plt.legend()
plt.show()

# %%
 #6. Write a Python program to perform an independent T-test and interpret the results
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.proportion import proportions_ztest

from scipy import stats

group1 = np.random.normal(50, 5, 30)
group2 = np.random.normal(52, 5, 30)
t_stat, p_val = stats.ttest_ind(group1, group2)
print(f"Independent T-Test:\nT = {t_stat:.4f}, P = {p_val:.4f}")
# Out:
# Independent T-Test:
# T = -4.0780, P = 0.0001

# %%
 #7. Perform a paired sample T-test using Python and visualize the comparison results
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.proportion import proportions_ztest

before = np.random.normal(100, 10, 30)
after = before + np.random.normal(5, 3, 30)
t_stat, p_val = stats.ttest_rel(before, after)
print(f"Paired T-Test:\nT = {t_stat:.4f}, P = {p_val:.4f}")

plt.plot(before, label='Before')
plt.plot(after, label='After')
plt.title("Before vs After")
plt.legend()
plt.show()
# Out:
# Paired T-Test:
# T = -9.3606, P = 0.0000

# %%
#8. Simulate data and perform both Z-test and T-test, then compare the results using Python
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.proportion import proportions_ztest

sample = np.random.normal(50, 10, 25)
pop_mean = 52

# Z-test
z_stat = (np.mean(sample) - pop_mean) / (10 / np.sqrt(len(sample)))
p_z = 2 * (1 - stats.norm.cdf(abs(z_stat)))

# T-test
t_stat, p_t = stats.ttest_1samp(sample, pop_mean)

print(f"Z-Test: Z = {z_stat:.4f}, P = {p_z:.4f}")
print(f"T-Test: T = {t_stat:.4f}, P = {p_t:.4f}")
# Out:
# Z-Test: Z = -1.1643, P = 0.2443
# T-Test: T = -1.0809, P = 0.2905

# %%
 #9. Write a Python function to calculate the confidence interval for a sample mean and explain its significance
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.proportion import proportions_ztest

def confidence_interval(data, confidence=0.95):
    n = len(data)
    mean = np.mean(data)
    se = stats.sem(data)
    margin = se * stats.t.ppf((1 + confidence) / 2., n - 1)
    return mean - margin, mean + margin

sample = np.random.normal(100, 15, 30)
low, high = confidence_interval(sample)
print(f"95% Confidence Interval: ({low:.2f}, {high:.2f})")
# Out:
# 95% Confidence Interval: (92.60, 101.57)

# %%
#10. Write a Python program to calculate the margin of error for a given confidence level using sample data
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.proportion import proportions_ztest

def margin_of_error(data, confidence=0.95):
    n = len(data)
    se = stats.sem(data)
    t_crit = stats.t.ppf((1 + confidence) / 2., df=n-1)
    return t_crit * se

sample_data = np.random.normal(100, 10, 50)
moe = margin_of_error(sample_data)
print(f"Margin of Error: ±{moe:.4f}")
# Out:
# Margin of Error: ±2.9848

# %%
#11. Implement a Bayesian inference method using Bayes' Theorem in Python and explain the process

def bayes_theorem(prior_A, prob_B_given_A, prob_B):
    return (prob_B_given_A * prior_A) / prob_B

# Example: Disease test
prior = 0.01
sensitivity = 0.99
false_positive_rate = 0.05
prob_B = (sensitivity * prior) + (false_positive_rate * (1 - prior))

posterior = bayes_theorem(prior, sensitivity, prob_B)
print(f"Posterior Probability = {posterior:.4f}")
# Out:
# Posterior Probability = 0.1667

# %%
#12. Perform a Chi-square test for independence between two categorical variables in Python
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.proportion import proportions_ztest

observed = np.array([[30, 10], [20, 40]])
chi2, p, dof, expected = stats.chi2_contingency(observed)
print(f"Chi-square Test:\nChi2 = {chi2:.4f}, P = {p:.4f}")
# Out:
# Chi-square Test:
# Chi2 = 15.0417, P = 0.0001

# %%
 #13. Write a Python program to calculate the expected frequencies for a Chi-square test based on observed data
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.proportion import proportions_ztest

print("Expected Frequencies:")
print(expected)
# Out:
# Expected Frequencies:
# [[20. 20.]
#  [30. 30.]]

# %%
#14. Perform a goodness-of-fit test using Python to compare the observed data to an expected distribution
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.proportion import proportions_ztest

observed_counts = np.array([50, 30, 20])
expected_counts = np.array([40, 40, 20])
chi2, p_val = stats.chisquare(f_obs=observed_counts, f_exp=expected_counts)
print(f"Chi-square Goodness-of-Fit:\nChi2 = {chi2:.4f}, P = {p_val:.4f}")
# Out:
# Chi-square Goodness-of-Fit:
# Chi2 = 5.0000, P = 0.0821

# %%
#15. Create a Python script to simulate and visualize the Chi-square distribution and discuss its characteristics
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.proportion import proportions_ztest

x = np.linspace(0, 20, 1000)
y = stats.chi2.pdf(x, df=4)

plt.plot(x, y, label="Chi-square (df=4)")
plt.title("Chi-square Distribution")
plt.xlabel("X")
plt.ylabel("PDF")
plt.legend()
plt.grid(True)
plt.show()

# %%
#16. Implement an F-test using Python to compare the variances of two random samples
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.proportion import proportions_ztest

def f_test(sample1, sample2):
    var1 = np.var(sample1, ddof=1)
    var2 = np.var(sample2, ddof=1)
    f_stat = var1 / var2
    dfn = len(sample1) - 1
    dfd = len(sample2) - 1
    p_value = 1 - stats.f.cdf(f_stat, dfn, dfd)
    return f_stat, p_value

s1 = np.random.normal(50, 10, 30)
s2 = np.random.normal(50, 5, 30)
f_stat, p_val = f_test(s1, s2)
print(f"F-test:\nF = {f_stat:.4f}, P-value = {p_val:.4f}")
# Out:
# F-test:
# F = 3.3159, P-value = 0.0009

# %%
#17. Write a Python program to perform an ANOVA test to compare means between multiple groups and interpret the results

group1 = np.random.normal(60, 10, 30)
group2 = np.random.normal(62, 10, 30)
group3 = np.random.normal(59, 10, 30)

f_stat, p_val = stats.f_oneway(group1, group2, group3)
print(f"ANOVA Test:\nF = {f_stat:.4f}, P-value = {p_val:.4f}")
# Out:
# ANOVA Test:
# F = 0.7773, P-value = 0.4628

# %%
 #18. Perform a one-way ANOVA test using Python and plot the results

plt.boxplot([group1, group2, group3], labels=["Group 1", "Group 2", "Group 3"])
plt.title("One-Way ANOVA - Boxplot")
plt.ylabel("Values")
plt.show()
# Out:
# /tmp/ipython-input-27-3298548596.py:3: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([group1, group2, group3], labels=["Group 1", "Group 2", "Group 3"])

# %%
#19. Write a Python function to check the assumptions (normality, independence, and equal variance) for ANOVA

def check_anova_assumptions(*groups):
    for i, group in enumerate(groups, 1):
        stat, p = stats.shapiro(group)
        print(f"Group {i} Normality: W={stat:.4f}, p={p:.4f}")
    stat, p = stats.levene(*groups)
    print(f"Equal Variance (Levene's Test): W={stat:.4f}, p={p:.4f}")

check_anova_assumptions(group1, group2, group3)
# Out:
# Group 1 Normality: W=0.9587, p=0.2874
# Group 2 Normality: W=0.9823, p=0.8838
# Group 3 Normality: W=0.9926, p=0.9987
# Equal Variance (Levene's Test): W=1.5034, p=0.2281

# %%
# 20. Perform a two-way ANOVA test using Python and visualize the results

import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols

# Simulate data
np.random.seed(0)
df = pd.DataFrame({
    'Score': np.random.normal(60, 5, 60),
    'Method': ['A', 'B'] * 30,
    'Instructor': ['X'] * 20 + ['Y'] * 20 + ['Z'] * 20
})

model = ols("Score ~ C(Method) + C(Instructor) + C(Method):C(Instructor)", data=df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
print("Two-Way ANOVA Results:\n", anova_table)
# Out:
# Two-Way ANOVA Results:
#                                sum_sq    df         F    PR(>F)
# C(Method)                   0.017277   1.0  0.000711  0.978829
# C(Instructor)             232.853491   2.0  4.789654  0.012165
# C(Method):C(Instructor)   139.392828   2.0  2.867225  0.065548
# Residual                 1312.630286  54.0       NaN       NaN

# %%
#21. Write a Python program to visualize the F-distribution and discuss its use in hypothesis testing

x = np.linspace(0, 5, 1000)
y = stats.f.pdf(x, dfn=5, dfd=10)

plt.plot(x, y, label="F-distribution (df1=5, df2=10)")
plt.title("F-distribution Curve")
plt.xlabel("F-statistic")
plt.ylabel("Density")
plt.legend()
plt.show()

# %%
# 22. Perform a one-way ANOVA test in Python and visualize the results with boxplots

# Already done in Q17 & Q18; repeating boxplot here
plt.boxplot([group1, group2, group3], labels=["Group 1", "Group 2", "Group 3"])
plt.title("Group Means via Boxplot")
plt.show()
# Out:
# /tmp/ipython-input-31-3242014272.py:4: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([group1, group2, group3], labels=["Group 1", "Group 2", "Group 3"])

# %%
#23. Simulate random data from a normal distribution, then perform hypothesis testing to evaluate the means

data = np.random.normal(100, 15, 50)
t_stat, p_val = stats.ttest_1samp(data, popmean=105)
print(f"T-test for Mean = 105:\nT = {t_stat:.4f}, P-value = {p_val:.4f}")
# Out:
# T-test for Mean = 105:
# T = -1.6301, P-value = 0.1095

# %%
 #24. Perform a hypothesis test for population variance using a Chi-square distribution

sample = np.random.normal(100, 10, 30)
sample_var = np.var(sample, ddof=1)
chi2_stat = (len(sample) - 1) * sample_var / (10**2)
p_val = 1 - stats.chi2.cdf(chi2_stat, df=len(sample) - 1)
print(f"Chi-Square Test for Variance:\nChi2 = {chi2_stat:.4f}, P = {p_val:.4f}")
# Out:
# Chi-Square Test for Variance:
# Chi2 = 21.2488, P = 0.8499

# %%
#25. Write a Python script to perform a Z-test for comparing proportions between two groups

from statsmodels.stats.proportion import proportions_ztest

success = np.array([40, 50])
trials = np.array([100, 120])
z_stat, p_val = proportions_ztest(success, trials)
print(f"Z-Test for Proportions:\nZ = {z_stat:.4f}, P-value = {p_val:.4f}")
# Out:
# Z-Test for Proportions:
# Z = -0.2504, P-value = 0.8023

# %%
#26. Implement an F-test for comparing the variances of two datasets, then interpret and visualize the results

s1 = np.random.normal(50, 10, 30)
s2 = np.random.normal(50, 5, 30)
f_val = np.var(s1, ddof=1) / np.var(s2, ddof=1)
dfn, dfd = len(s1) - 1, len(s2) - 1
p_val = 1 - stats.f.cdf(f_val, dfn, dfd)

plt.hist([s1, s2], label=["Sample 1", "Sample 2"], bins=10, alpha=0.7)
plt.title("Histogram Comparison for F-test")
plt.legend()
plt.show()
print(f"F-test Variance Comparison:\nF = {f_val:.4f}, P = {p_val:.4f}")
# Out:
# F-test Variance Comparison:
# F = 4.5030, P = 0.0001

# %%
 #27. Perform a Chi-square test for goodness of fit with simulated data and analyze the results

observed = np.array([18, 22, 20])
expected = np.array([20, 20, 20])
chi2, p_val = stats.chisquare(observed, f_exp=expected)
print(f"Chi-square Goodness-of-Fit:\nChi2 = {chi2:.4f}, P = {p_val:.4f}")
# Out:
# Chi-square Goodness-of-Fit:
# Chi2 = 0.4000, P = 0.8187
